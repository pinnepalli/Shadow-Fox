# %% [markdown]
# **Matplotlib Graphs**
#
# **1 Line Plot**
#
# Description: Displays information as a series of data points connected by straight line segments. Useful for showing trends over time. Use Case: Tracking changes over periods, such as stock prices or temperature variations.

# %%
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 7, 5]
y = [2, 3, 5, 8, 11]

# Create line plot
plt.plot(x, y, marker='o')
plt.title('Line Plot ')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %% [markdown]
# **2.Scatter Plot**
#
# Description: Uses Cartesian coordinates to display values for two variables for a set of data. Ideal for observing relationships between variables. Use Case: Identifying correlations, clusters, and outliers in data.

# %%
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 7, 5]
y = [2, 4, 5, 7, 11]

# Create scatter plot
plt.scatter(x, y, color='blue')
plt.title('Scatter Plot Example')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %% [markdown]
# **3.Bar Chart**
#
# Description: Represents categorical data with rectangular bars. The length of each bar is proportional to the value it represents. Use Case: Comparing different categories or groups.

# %%
import matplotlib.pyplot as plt

# Sample data
categories = ['A', 'B', 'C', 'D']
values = [5, 4, 1, 8]

# Create bar chart
plt.bar(categories, values, color='blue')
plt.title('Bar Chart Example')
plt.xlabel('Categories')
plt.ylabel('Values')
plt.show()

# %% [markdown]
# **4 Histogram**
#
# Description: Shows the distribution of a dataset by grouping data into bins and displaying the frequency of data points in each bin. Use Case: Understanding the distribution and spread of data.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
data = np.random.randn(1000)

# Create histogram
plt.hist(data, bins=30, color='red', edgecolor='black')
plt.title('Histogram Example')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# **5 Pie Chart**
#
# Description: Displays data as slices of a circle, where each slice represents a proportion of the whole. Use Case: Showing percentage or proportional data.

# %%
import matplotlib.pyplot as plt

# Sample data
labels = ['Category A', 'Category B', 'Category C']
sizes = [40, 30, 50]

# Create pie chart
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title('Pie Chart Example')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# **Seaborn Graphs**
#
# **Line Plot**
#
# Description: Similar to Matplotlib's line plot but with additional features for statistical analysis. Use Case: Visualizing trends with confidence intervals.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
tips = sns.load_dataset('tips')

# Create line plot
sns.lineplot(data=tips, x='total_bill', y='tip', ci='sd')
plt.title('Seaborn Line Plot Example')
plt.show()
# Out:
# <ipython-input-3-983460d2c165>:8: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.lineplot(data=tips, x='total_bill', y='tip', ci='sd')

# %% [markdown]
# **Scatter Plot**
#
# Description: Enhanced scatter plots with support for hue, size, and style. Use Case: Exploring relationships with additional categorical variables.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
tips = sns.load_dataset('tips')

# Create scatter plot
sns.scatterplot(data=tips, x='total_bill', y='tip', hue='day', style='sex')
plt.title('Seaborn Scatter Plot Example')
plt.show()

# %% [markdown]
# **Bar Plot**
#
# Description: Simplified bar charts with automatic aggregation and error bars. Use Case: Comparing categorical data with built-in statistical summaries. Example: Code & Output :

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
tips = sns.load_dataset('tips')

# Create bar chart
sns.barplot(data=tips, x='day', y='total_bill', ci='sd')
plt.title('Seaborn Bar Chart Example')
plt.show()
# Out:
# <ipython-input-5-a235af8358a1>:8: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=tips, x='day', y='total_bill', ci='sd')

# %% [markdown]
# **Histogram**
#
# Description: Similar to Matplotlib's histogram but with better aesthetics and automatic handling of bins. Use Case: Visualizing the distribution of data with kernel density estimates.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
tips = sns.load_dataset('tips')

# Create histogram
sns.histplot(data=tips, x='total_bill', bins=30, kde=True, color='green')
plt.title('Seaborn Histogram Example')
plt.show()

# %% [markdown]
# **Box Plot**
#
# Description: Displays the distribution of data based on a five-number summary: minimum, first quartile, median, third quartile, and maximum. Use Case: Identifying outliers and understanding the spread of data.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
tips = sns.load_dataset('tips')

# Create box plot
sns.boxplot(data=tips, x='day', y='total_bill', hue='smoker')
plt.title('Seaborn Box Plot Example')
plt.show()
